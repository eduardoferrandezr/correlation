# %%
import pandas as pd
from pandas_datareader import data
import datetime

start = datetime.datetime(2015, 1, 1)
end = datetime.datetime(2015, 12, 31)

symbols = ('SAN.MC', 'GAM.MC', 'BBVA.MC', 'REE.MC', 'ENG.MC', 'REP.MC')

prices_df = pd.DataFrame()
for symbol in symbols:
    df = data.DataReader(symbol, 'yahoo', start, end)
    prices_df.loc[:, symbol] = df['Adj Close']

prices_df.tail()
# Out:
#              SAN.MC  GAM.MC  BBVA.MC  REE.MC  ENG.MC  REP.MC
# Date
# 2015-12-25  4.58102  15.980  6.61202  71.639  24.356   10.94
# 2015-12-28  4.47360  15.585  6.53105  71.314  24.328   10.49
# 2015-12-29  4.51364  16.110  6.54153  72.672  24.921   10.48
# 2015-12-30  4.50290  15.970  6.51199  72.207  24.775   10.30
# 2015-12-31  4.45114  15.820  6.41959  71.770  24.478   10.12

# %%
corr_df = prices_df.corr(method='pearson')

corr_df
# Out:
#            SAN.MC    GAM.MC   BBVA.MC    REE.MC    ENG.MC    REP.MC
# SAN.MC   1.000000 -0.249265  0.878500 -0.446722 -0.231107  0.969645
# GAM.MC  -0.249265  1.000000  0.062091  0.532410  0.209075 -0.301150
# BBVA.MC  0.878500  0.062091  1.000000 -0.275203 -0.153321  0.821422
# REE.MC  -0.446722  0.532410 -0.275203  1.000000  0.849807 -0.444933
# ENG.MC  -0.231107  0.209075 -0.153321  0.849807  1.000000 -0.179946
# REP.MC   0.969645 -0.301150  0.821422 -0.444933 -0.179946  1.000000

# %%
corr_matrix = corr_df.as_matrix()
corr_matrix
# Out:
# array([[ 1.        , -0.24926507,  0.8785    , -0.44672203, -0.23110739,
#          0.96964524],
#        [-0.24926507,  1.        ,  0.06209086,  0.53240995,  0.20907518,
#         -0.30114976],
#        [ 0.8785    ,  0.06209086,  1.        , -0.27520279, -0.15332104,
#          0.82142208],
#        [-0.44672203,  0.53240995, -0.27520279,  1.        ,  0.84980689,
#         -0.44493331],
#        [-0.23110739,  0.20907518, -0.15332104,  0.84980689,  1.        ,
#         -0.17994649],
#        [ 0.96964524, -0.30114976,  0.82142208, -0.44493331, -0.17994649,
#          1.        ]])

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()

N = len(symbols)
factors = list(symbols)
x = []
y = []
colors = []
for i in range(N):
    for j in range(N):
        x.append(symbols[j])
        y.append(symbols[i])
        cor = corr_matrix[i, j]
        rgb = (int(abs(cor) * 255), 0, int((1 - abs(cor)) * 255))
        colors.append('#%02x%02x%02x' % rgb)

p2 = figure(x_range=factors, y_range=factors)

p2.rect(x, y, color=colors, width=1, height=1)

show(p2)  # open a browser
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bc51fa53-b9d7-46f3-8a98-15c6242056b7">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="9d483b91-7f8f-4e8b-96bc-572b9789280e"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9d483b91-7f8f-4e8b-96bc-572b9789280e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9d483b91-7f8f-4e8b-96bc-572b9789280e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a60904de-4dfa-45c5-acc7-87837738e8fc":{"roots":{"references":[{"attributes":{"plot":{"id":"a50763ac-1ec3-4036-b51f-c1e5260c43ac","subtype":"Figure","type":"Plot"}},"id":"01b4970c-1a00-4271-9335-7d5941f66793","type":"HelpTool"},{"attributes":{"fill_color":{"field":"fill_color"},"height":{"units":"data","value":1},"line_color":{"field":"line_color"},"width":{"units":"data","value":1},"x":{"field":"x"},"y":{"field":"y"}},"id":"585f91ae-2bf9-4f22-8fa8-efd8b3b1aed9","type":"Rect"},{"attributes":{"overlay":{"id":"4e6ac859-b63b-4799-8825-cc8d3172587c","type":"BoxAnnotation"},"plot":{"id":"a50763ac-1ec3-4036-b51f-c1e5260c43ac","subtype":"Figure","type":"Plot"}},"id":"50743aa5-3801-49d6-b456-9669c54783f0","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"de9b982e-c055-4722-99d6-b9d5ed0313c2","type":"CategoricalTickFormatter"},"plot":{"id":"a50763ac-1ec3-4036-b51f-c1e5260c43ac","subtype":"Figure","type":"Plot"},"ticker":{"id":"c4fb02e0-27e1-4aa0-a372-afc260d10c5c","type":"CategoricalTicker"}},"id":"16c95f2e-5e2f-4875-a46a-09ea7d22c4db","type":"CategoricalAxis"},{"attributes":{"below":[{"id":"16c95f2e-5e2f-4875-a46a-09ea7d22c4db","type":"CategoricalAxis"}],"left":[{"id":"8cc686f6-b4ee-4e80-9935-5184acf250af","type":"CategoricalAxis"}],"renderers":[{"id":"16c95f2e-5e2f-4875-a46a-09ea7d22c4db","type":"CategoricalAxis"},{"id":"7e72b363-a980-457d-92ab-3676ee66ee4d","type":"Grid"},{"id":"8cc686f6-b4ee-4e80-9935-5184acf250af","type":"CategoricalAxis"},{"id":"bcc372be-1283-4af2-a63e-2667a9742f3d","type":"Grid"},{"id":"4e6ac859-b63b-4799-8825-cc8d3172587c","type":"BoxAnnotation"},{"id":"e4ea18de-4f0b-459e-a8bb-2abede7e1ec7","type":"GlyphRenderer"}],"tool_events":{"id":"5136ebc1-f49a-4ad7-a7bf-de3bf4a94bb8","type":"ToolEvents"},"tools":[{"id":"137314fc-83e3-4f80-9d03-f0ef345269b1","type":"PanTool"},{"id":"d8b0e2b5-2e8e-4740-89f1-c4551eb4b637","type":"WheelZoomTool"},{"id":"50743aa5-3801-49d6-b456-9669c54783f0","type":"BoxZoomTool"},{"id":"83fdde4b-40eb-47b8-92de-a0e271c3fa26","type":"PreviewSaveTool"},{"id":"e1ab1ca0-d4fd-4ba4-8a81-e1b217ca82f1","type":"ResizeTool"},{"id":"665185c7-fa1c-4340-b66a-a4390f0836a3","type":"ResetTool"},{"id":"01b4970c-1a00-4271-9335-7d5941f66793","type":"HelpTool"}],"x_range":{"id":"25edbc2f-5a8f-4c39-a4fb-6705e00f50b9","type":"FactorRange"},"y_range":{"id":"d0c97b1f-d39c-4d66-8fa4-9abb1201fe76","type":"FactorRange"}},"id":"a50763ac-1ec3-4036-b51f-c1e5260c43ac","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"f51a9e9a-4600-4efe-9f47-df36b2173390","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"factors":["SAN.MC","GAM.MC","BBVA.MC","REE.MC","ENG.MC","REP.MC"]},"id":"d0c97b1f-d39c-4d66-8fa4-9abb1201fe76","type":"FactorRange"},{"attributes":{},"id":"de9b982e-c055-4722-99d6-b9d5ed0313c2","type":"CategoricalTickFormatter"},{"attributes":{},"id":"c4fb02e0-27e1-4aa0-a372-afc260d10c5c","type":"CategoricalTicker"},{"attributes":{"data_source":{"id":"823b8586-4d88-45f4-9110-1bc067267b2b","type":"ColumnDataSource"},"glyph":{"id":"585f91ae-2bf9-4f22-8fa8-efd8b3b1aed9","type":"Rect"},"hover_glyph":null,"nonselection_glyph":{"id":"ea6cdf8a-eea3-4e2d-89c8-06fb1ae817b0","type":"Rect"},"selection_glyph":null},"id":"e4ea18de-4f0b-459e-a8bb-2abede7e1ec7","type":"GlyphRenderer"},{"attributes":{},"id":"d103394f-c6fe-4b8c-bbb5-fe0b3ce22a42","type":"CategoricalTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4e6ac859-b63b-4799-8825-cc8d3172587c","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"a50763ac-1ec3-4036-b51f-c1e5260c43ac","subtype":"Figure","type":"Plot"}},"id":"d8b0e2b5-2e8e-4740-89f1-c4551eb4b637","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"a50763ac-1ec3-4036-b51f-c1e5260c43ac ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[4]</strong>&gt;</code></p>
